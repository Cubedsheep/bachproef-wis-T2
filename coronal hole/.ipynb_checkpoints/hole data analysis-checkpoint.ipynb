# %% [markdown]
# # Data analysis coronal hole model

# %% [markdown]
# ## Import necesarry packages

# %%
import script.pyPLUTO as pp
import matplotlib.pyplot as plt
import matplotlib as mpl

import numpy as np
import pandas as pd
from scipy.ndimage import convolve

# some commonly used constants
CONST_mp = 1.67262171e-24  # gr

# %%
mpl.rcParams["figure.dpi"] = 150    # about the dpi for a 15 inch 1080p laptop, makes sure the displayed plots are the real size 
#mpl.rcParams["figure.dpi"] = 600

mpl.rcParams["figure.figsize"] = (6, 3)
mpl.rcParams["axes.labelsize"] = 12

mpl.rcParams["axes.formatter.limits"] = (-4, 4)

mpl.rcParams["axes.prop_cycle"] = mpl.cycler(color=["xkcd:royal blue", "xkcd:vermillion", "xkcd:orange", 
                                                    "xkcd:magenta", "xkcd:lime", "xkcd:yellow", "grey"])

mpl.rcParams["lines.linewidth"] = 1
mpl.rcParams["axes.linewidth"] = .5

mpl.rcParams["font.size"] = 12

mpl.rcParams["text.usetex"] = True


#mpl.rcParams["figure.facecolor"] = "#fffbf0"
#mpl.rcParams["axes.facecolor"] = "#fffbf0"
#mpl.rcParams["savefig.facecolor"] = '#fffbf0'

# %% [markdown]
# Usefull functions

# %%
def get_extent(file, firstline):
    """this functions retrieves the extent of the grid (in code-units) and number of points from the grid.out 
    file in one dimension (starting at firstline)
    
    file: the grid.out file
    firstline: the line in the file to look for the number of points in that dimension"""
    with open(file, "r") as gridfile:
        lines = gridfile.readlines()
        # get the number of points
        NUM_POINTS = int(lines[firstline])

        # get the extent of the x-axis (in code units)
        # the first line of the grid, so minimum coordinate
        line = lines[firstline+1]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_min = float(parts[1])
        # the last line
        line = lines[firstline+NUM_POINTS]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_max = float(parts[2])
    
    return (NUM_POINTS, (d_min, d_max))

# %% [markdown]
# Import metadata about the output such as the time corresponding to each files and conversion factors from code units to physical units

# %%
# specify the directories where the data is stored and where the output should be stored
DATA_DIR = "data/hole-raw/"
OUT_DIR = "data/images/frames/"

# get info about the stored data
file_data = pd.read_csv(DATA_DIR+"dbl.out", sep=" ", names=["index", "t", "dt", "step", "type", "little", "rho",
                                                            "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"])
# delete columns that are not needed
for column in ["index", "type", "little", "rho", "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"]:
    del file_data[column]

# define the conversion factors
UNIT_DENSITY = 1e9*CONST_mp
UNIT_LENGTH = 1e8 # cm
UNIT_VELOCITY = 1e8 # cm/s

X_POINTS = 0
Y_POINTS = 0
X_EXTENT = (0,0)
Y_EXTENT = (0,0)

# get the extend of the grid
# get the extent of the x-axis (in code units)
X_POINTS, X_EXTENT = get_extent(DATA_DIR+"grid.out", 9)
# get the extent of the y-axis
Y_POINTS, Y_EXTENT = get_extent(DATA_DIR+"grid.out", 10+X_POINTS)

# number of files saved
N = len(file_data["t"])

# %% [markdown]
# ## 12 plots of wave interaction

# %% [markdown]
# ### Pressure

# %% [markdown]
# fig, ax = plt.subplots(4,3,figsize=(6,8))
#
# N = [80+7*i for i in range(0,12)]
#
# T = file_data["t"].values
# extent_temp = X_EXTENT + Y_EXTENT
# extent = [value*UNIT_LENGTH for value in extent_temp]
# ex = [x*1e-11 for x in extent]
#
# for i in range(12):
#     column = i%3
#     row = i//3
#     axis = ax[row][column]
#
#     D = pp.pload(N[i], w_dir=DATA_DIR)
#     im=axis.imshow(D.rho, vmin=0.097, vmax=0.11, extent=ex, cmap="plasma")
#
#     axis.get_xaxis().set_visible(False)
#     axis.get_yaxis().set_visible(False)
#
#     axis.set_title("t=%.0f"%T[N[i]])
#
# plt.colorbar(im, ax=ax)
#
# # switch the axes on the side on
# for column in range(3):
#     ax[3][column].get_xaxis().set_visible(True)
# for row in range(4):
#     ax[row][0].get_yaxis().set_visible(True)
#
# fig.text(0.5, 0.07, r"distance $[10^{11}cm]$", va='center', ha="center")
# fig.text(0.03, 0.5, r"distance $[10^{11}cm]$", va='center', rotation=90)
#
# fig.savefig("../verslag/images/coronal-plume.pdf")

# %% [markdown]
# ### density

# %% [markdown]
# fig, ax = plt.subplots(4,3,figsize=(6,8))
#
# N = [11*i for i in range(0,12)]
#
# T = file_data["t"].values
# extent_temp = X_EXTENT + Y_EXTENT
# extent = [value*UNIT_LENGTH for value in extent_temp]
# ex = [x*1e-11 for x in extent]
#
# for i in range(12):
#     column = i%3
#     row = i//3
#     axis = ax[row][column]
#
#     D = pp.pload(N[i], w_dir=DATA_DIR)
#     im=axis.imshow(D.rho, vmin=0.098, vmax=0.13, extent=ex, cmap="plasma")
#
#     axis.get_xaxis().set_visible(False)
#     axis.get_yaxis().set_visible(False)
#
#     axis.set_title("t=%.0f"%T[N[i]])
#
# plt.colorbar(im, ax=ax, fraction=0.04, pad=0.01)
#
# # switch the axes on the side on
# for column in range(3):
#     ax[3][column].get_xaxis().set_visible(True)
# for row in range(4):
#     ax[row][0].get_yaxis().set_visible(True)
#
# fig.text(0.5, 0.07, r"distance $[10^{11}cm]$", va='center', ha="center")
# fig.text(0.03, 0.5, r"distance $[10^{11}cm]$", va='center', rotation=90)
#
# #fig.savefig("../verslag/images/coronal-hole.pdf")

# %% [markdown]
# ## Make plots of the density and pressure to visualize the wave

# %% [markdown]
# test with one frame

# %%
T = file_data["t"].values
extent_temp = X_EXTENT + Y_EXTENT
extent = [value*UNIT_LENGTH*1e-11 for value in extent_temp]

def rho_prs(D, i, save=False, name=""):
    fig, ax = plt.subplots(1,2,figsize=(12.8, 7.2))

    axis = ax[0]
    im=axis.imshow(D.prs, vmin=0.0245, vmax=0.0283, extent=extent, cmap="gnuplot")
    cbar = fig.colorbar(im, ax=axis, fraction=0.0465, pad=0.02)
    cbar.ax.set_ylabel('pressure [code units]', rotation=270, fontsize=12, labelpad=15)
    axis.set_title("Pressure", fontsize=16)

    vmin=0.97
    vmax = 1.08
    axis = ax[1]
    im=axis.imshow(D.rho, vmin=vmin, vmax=vmax, extent=extent, cmap="gnuplot")
    cbar = fig.colorbar(im, ax=axis, fraction=0.0465, pad=0.02)
    cbar.ax.set_ylabel('density [code units]', rotation=270, fontsize=12, labelpad=15)
    axis.set_title("Density", fontsize=16)


    fig.suptitle("time: %.2e [s]"%(T[i]), y=0.99, fontsize=24)
    #ax.set_xlabel("x-axis [cm]")
    #ax.set_ylabel("y-axis [cm]")

    fig.text(0.5, 0.025, r"distance $[10^{11}cm]$", va='center', ha="center")
    fig.text(0.005, 0.6, r"distance $[10^{11}cm]$", va='center', rotation=90)

    plt.tight_layout()
    
    if save:
        fig.savefig(name)
    
    return fig

i = 106
D = pp.pload(i, w_dir=DATA_DIR+"/")
rho_prs(D, i, save=True, name="test")
plt.show()
# Out:
# Reading Data file : data/hole-raw//data.0106.dbl

# %% [markdown]
# Import for each output file the density, plot it and save the output

# %% [markdown]
# ## Density outside and inside plume side by side

# %%
## preparation

T = file_data["t"].values
extent_temp = X_EXTENT + Y_EXTENT
extent = [value*UNIT_LENGTH*1e-11 for value in extent_temp]

# region cut out for wave inside of plume
# select region
MIN = 400
MAX = 624
min_coord = (X_EXTENT[0] + (X_EXTENT[1]-X_EXTENT[0])*MIN/1024)/(1000)
max_coord = (X_EXTENT[0] + (X_EXTENT[1]-X_EXTENT[0])*MAX/1024)/(1000)
# pressure inside plume
ex = [value*UNIT_LENGTH*(MAX-MIN)/1023*1e-11 for value in extent_temp]
# circle of characteristic diameter
d = 150/X_EXTENT[1]
THETA = np.linspace(0,2*np.pi,1000)
X_circ = d*np.cos(THETA)
Y_circ = d*np.sin(THETA)

## end preparation
def plume_zoom(D, i, save=False, name=""):
    fig, ax = plt.subplots(1,2,figsize=(12.8, 7.2))

    # select cutoffs
    if i < 105:
        vmin=0.98
    else:
        vmin=0.98
    vmax = 1.08

    # pressure outside hole
    axis = ax[0]
    im=axis.imshow(D.rho, vmin=vmin, vmax=vmax, extent=extent, cmap="gnuplot")
    cbar = fig.colorbar(im, ax=axis, fraction=0.0465, pad=0.02)
    cbar.ax.set_ylabel('Density [code units]', rotation=270, fontsize=12, labelpad=15)
    axis.set_title("Density", fontsize=16)
    # draw box of the inset
    axis.plot([min_coord, min_coord], [min_coord, max_coord], "k--", lw=1.2)
    axis.plot([min_coord, max_coord], [max_coord, max_coord], "k--", lw=1.2)
    axis.plot([max_coord, max_coord], [max_coord, min_coord], "k--", lw=1.2)
    axis.plot([max_coord, min_coord], [min_coord, min_coord], "k--", lw=1.2)
    # draw the circle of characteristic width for the plume/hole
    axis.plot(X_circ,Y_circ,"-.w",lw=1.2)
    # small ticks
    axis.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())
    axis.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())

    vmin = 0.08
    vmax = 0.15

    # pressure inside plume
    axis = ax[1]
    im=axis.imshow(D.rho[MIN:MAX,MIN:MAX], vmin=vmin, vmax=vmax, extent=ex, cmap="gnuplot_r")
    cbar = fig.colorbar(im, ax=axis, fraction=0.0465, pad=0.02)
    cbar.ax.set_ylabel('Density [code units]', rotation=270, fontsize=12, labelpad=15)
    axis.set_title("Density inside plume", fontsize=16)
    axis.plot(X_circ,Y_circ,"-.w",lw=1.2)
    axis.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())
    axis.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())


    fig.suptitle("time: %.2e [s]"%(T[i]), y=0.99, fontsize=24)
    #ax.set_xlabel("x-axis [cm]")
    #ax.set_ylabel("y-axis [cm]")

    fig.text(0.5, 0.025, r"distance $[10^{11}cm]$", va='center', ha="center")
    fig.text(0.005, 0.6, r"distance $[10^{11}cm]$", va='center', rotation=90)

    plt.tight_layout()
    
    if save:
        fig.savefig(name)

    return fig

plume_zoom(D,i)
plt.show()

# %%
X = np.linspace(X_EXTENT[0], X_EXTENT[1], X_POINTS)
ref = pp.pload(0, DATA_DIR)
SECTION = int(1/2*X_POINTS)

def sections(D, i, save=False, name=""):
    fig, ax = plt.subplots(3,1, figsize=(6,6))

    # find the front of the wave
    large = (D.rho[:,0]/ref.rho[:,0])>1.05 # the large excitations
    indexes = np.where(large == 1)
    try:
        index = indexes[0][-1]
        physical_position = X_EXTENT[0] + (X_EXTENT[1]-X_EXTENT[0])*index/X_POINTS
    except:
        physical_position = X_EXTENT[1]

    # outside
    axis = ax[0]
    axis.set_ylim(0.97,1.08)
    axis.plot(X, D.rho[:,SECTION])
    axis.plot([physical_position, physical_position], [-10,10], '--')
    axis.get_xaxis().set_visible(False)
    axis.set_ylabel(r"density [$10^9 cm^{-3}$]")
    axis.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())
    axis.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())

    # relative
    axis = ax[1]
    axis.plot(X, D.rho[:,SECTION]/ref.rho[:,SECTION])
    axis.plot([physical_position, physical_position], [-10,10], '--')
    axis.set_ylim(-0.2,2)
    axis.set_title("relative change in density with respect to initial condition")
    axis.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())
    axis.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())

    # inside
    axis = ax[2]
    ymin = np.min(D.rho[:,SECTION])-0.0005
    ymax = ymin+0.0015
    axis.plot(X, D.rho[:,SECTION])
    axis.plot([physical_position, physical_position], [-10,10], '--')
    axis.set_ylim(ymin,ymax)
    axis.set_xlim(-150,150)
    axis.set_ylabel(r"density [$10^8 cm^{-3}$]")
    axis.set_xlabel(r"distance [$10^{11}$ cm]")
    axis.yaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())
    axis.xaxis.set_minor_locator(mpl.ticker.AutoMinorLocator())
    
    fig.suptitle("time: %.2e [s]"%T[i], y=1)
    plt.tight_layout()
    
    if save:
        fig.savefig(name)
    
    return fig

i = 100
D = pp.pload(i, w_dir=DATA_DIR+"/")
sections(D, i)
plt.show()
# Out:
# Reading Data file : data/hole-raw/data.0000.dbl
# Reading Data file : data/hole-raw//data.0100.dbl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5ff73d645115> in <module>
#      58 D = pp.pload(i, w_dir=DATA_DIR+"/")
#      59 sections(D, i)
# ---> 60 plt.show()
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/pyplot.py in show(*args, **kw)
#     270     """
#     271     global _show
# --> 272     return _show(*args, **kw)
#     273
#     274
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2096
#    2097             try:
# -> 2098                 result = print_method(
#    2099                     filename,
#    2100                     dpi=dpi,
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args, **kwargs)
#     512         }
#     513
# --> 514         FigureCanvasAgg.draw(self)
#     515         if pil_kwargs is not None:
#     516             from PIL import Image
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     391              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     392               else nullcontext()):
# --> 393             self.figure.draw(self.renderer)
#     394             # A GUI class may be need to update a window using this draw, so
#     395             # don't forget to call the superclass.
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1733
#    1734             self.patch.draw(renderer)
# -> 1735             mimage._draw_list_compositing_images(
#    1736                 renderer, self, artists, self.suppressComposite)
#    1737
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2628             renderer.stop_rasterizing()
#    2629
# -> 2630         mimage._draw_list_compositing_images(renderer, self, artists)
#    2631
#    2632         renderer.close_group('axes')
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     135     if not_composite or not has_images:
#     136         for a in artists:
# --> 137             a.draw(renderer)
#     138     else:
#     139         # Composite any adjacent images together
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1226
#    1227         ticks_to_draw = self._update_ticks()
# -> 1228         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1229                                                                 renderer)
#    1230
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1171     def _get_tick_bboxes(self, ticks, renderer):
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1173         return ([tick.label1.get_window_extent(renderer)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in <listcomp>(.0)
#    1171     def _get_tick_bboxes(self, ticks, renderer):
#    1172         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1173         return ([tick.label1.get_window_extent(renderer)
#    1174                  for tick in ticks if tick.label1.get_visible()],
#    1175                 [tick.label2.get_window_extent(renderer)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     903             raise RuntimeError('Cannot get window extent w/o renderer')
#     904
# --> 905         bbox, info, descent = self._get_layout(self._renderer)
#     906         x, y = self.get_unitless_position()
#     907         x, y = self.get_transform().transform((x, y))
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     297             clean_line, ismath = self._preprocess_math(line)
#     298             if clean_line:
# --> 299                 w, h, d = renderer.get_text_width_height_descent(
#     300                     clean_line, self._fontproperties, ismath=ismath)
#     301             else:
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     201             texmanager = self.get_texmanager()
#     202             fontsize = prop.get_size_in_points()
# --> 203             w, h, d = texmanager.get_text_width_height_descent(
#     204                 s, fontsize, renderer=self)
#     205             return w, h, d
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     448         else:
#     449             # use dviread. It sometimes returns a wrong descent.
# --> 450             dvifile = self.make_dvi(tex, fontsize)
#     451             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     452                 page, = dvi
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     330             return self.make_dvi_preview(tex, fontsize)
#     331
# --> 332         basefile = self.get_basefile(tex, fontsize)
#     333         dvifile = '%s.dvi' % basefile
#     334         if not os.path.exists(dvifile):
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/texmanager.py in get_basefile(self, tex, fontsize, dpi)
#     162         s = ''.join([tex, self.get_font_config(), '%f' % fontsize,
#     163                      self.get_custom_preamble(), str(dpi or '')])
# --> 164         return os.path.join(
#     165             self.texcache, hashlib.md5(s.encode('utf-8')).hexdigest())
#     166
#
# ~/.virtualenvs/studie/lib/python3.8/posixpath.py in join(a, *p)
#      83             if b.startswith(sep):
#      84                 path = b
# ---> 85             elif not path or path.endswith(sep):
#      86                 path += b
#      87             else:
#
# KeyboardInterrupt:

# %% [markdown]
# ## plots for every snapshot

# %%
# initialize names to save the plots under
NAME_PRS_RHO = "data/images/both/frame"
NAME_ZOOM = "data/images/zoom/frame"
NAME_SECTION = "data/images/section/section%04iframe"%SECTION

### initialization "both"
#-----------------------------
T = file_data["t"].values
extent_temp = X_EXTENT + Y_EXTENT
extent = [value*UNIT_LENGTH*1e-11 for value in extent_temp]

### initialization "zoom"
#-----------------------------
ex = [value*UNIT_LENGTH*(MAX-MIN)/1023*1e-11 for value in extent_temp]

# region cut out for wave inside of plume
# select region
MIN = 400
MAX = 624
min_coord = (X_EXTENT[0] + (X_EXTENT[1]-X_EXTENT[0])*MIN/1024)/(1000)
max_coord = (X_EXTENT[0] + (X_EXTENT[1]-X_EXTENT[0])*MAX/1024)/(1000)
# pressure inside plume
ex = [value*UNIT_LENGTH*(MAX-MIN)/1023*1e-11 for value in extent_temp]
# circle of characteristic diameter
d = 150/X_EXTENT[1]
THETA = np.linspace(0,2*np.pi,1000)
X_circ = d*np.cos(THETA)
Y_circ = d*np.sin(THETA)

### initialization "section"
#------------------------------
X = np.linspace(X_EXTENT[0], X_EXTENT[1], X_POINTS)
ref = pp.pload(0, DATA_DIR)
SECTION = int(1/2*X_POINTS)


### loop over all data
for i in range(107,151):
    # read the data
    D = pp.pload(i, w_dir=DATA_DIR)
    # make the plot of both variables
    fig = rho_prs(D, i, save=True, name=NAME_PRS_RHO + "%03i.png"%i)
    #fig.savefig(NAME_PRS_RHO + "%03i.png"%i)
    plt.close(fig=fig)
    # make the plot for the zoom
    fig = plume_zoom(D, i, save=True, name=NAME_ZOOM + "%03i.png"%i)
    #fig.savefig(NAME_ZOOM + "%03i.png"%i)
    plt.close(fig=fig)
    # make the plot for the section
    fig = sections(D, i, save=True, name=NAME_SECTION + "%03i.png"%i)
    #fig.savefig(NAME_SECTION + "%03i.png"%i)
    plt.close(fig=fig)
# Out:
# Reading Data file : data/hole-raw/data.0000.dbl
# Reading Data file : data/hole-raw/data.0000.dbl
# Reading Data file : data/hole-raw/data.0001.dbl
# Reading Data file : data/hole-raw/data.0002.dbl
# Reading Data file : data/hole-raw/data.0003.dbl
# Reading Data file : data/hole-raw/data.0004.dbl
# Reading Data file : data/hole-raw/data.0005.dbl
# Reading Data file : data/hole-raw/data.0006.dbl
# Reading Data file : data/hole-raw/data.0007.dbl
# Reading Data file : data/hole-raw/data.0008.dbl
# Reading Data file : data/hole-raw/data.0009.dbl
# Reading Data file : data/hole-raw/data.0010.dbl
# Reading Data file : data/hole-raw/data.0011.dbl
# Reading Data file : data/hole-raw/data.0012.dbl
# Reading Data file : data/hole-raw/data.0013.dbl
# Reading Data file : data/hole-raw/data.0014.dbl
# Reading Data file : data/hole-raw/data.0015.dbl
# Reading Data file : data/hole-raw/data.0016.dbl
# Reading Data file : data/hole-raw/data.0017.dbl
# Reading Data file : data/hole-raw/data.0018.dbl
# Reading Data file : data/hole-raw/data.0019.dbl
# Reading Data file : data/hole-raw/data.0020.dbl
# Reading Data file : data/hole-raw/data.0021.dbl
# Reading Data file : data/hole-raw/data.0022.dbl
# Reading Data file : data/hole-raw/data.0023.dbl
# Reading Data file : data/hole-raw/data.0024.dbl
# Reading Data file : data/hole-raw/data.0025.dbl
# Reading Data file : data/hole-raw/data.0026.dbl
# Reading Data file : data/hole-raw/data.0027.dbl
# Reading Data file : data/hole-raw/data.0028.dbl
# Reading Data file : data/hole-raw/data.0029.dbl
# Reading Data file : data/hole-raw/data.0030.dbl
# Reading Data file : data/hole-raw/data.0031.dbl
# Reading Data file : data/hole-raw/data.0032.dbl
# Reading Data file : data/hole-raw/data.0033.dbl
# Reading Data file : data/hole-raw/data.0034.dbl
# Reading Data file : data/hole-raw/data.0035.dbl
# Reading Data file : data/hole-raw/data.0036.dbl
# Reading Data file : data/hole-raw/data.0037.dbl
# Reading Data file : data/hole-raw/data.0038.dbl
# Reading Data file : data/hole-raw/data.0039.dbl
# Reading Data file : data/hole-raw/data.0040.dbl
# Reading Data file : data/hole-raw/data.0041.dbl
# Reading Data file : data/hole-raw/data.0042.dbl
# Reading Data file : data/hole-raw/data.0043.dbl
# Reading Data file : data/hole-raw/data.0044.dbl
# Reading Data file : data/hole-raw/data.0045.dbl
# Reading Data file : data/hole-raw/data.0046.dbl
# Reading Data file : data/hole-raw/data.0047.dbl
# Reading Data file : data/hole-raw/data.0048.dbl
# Reading Data file : data/hole-raw/data.0049.dbl
# Reading Data file : data/hole-raw/data.0050.dbl
# Reading Data file : data/hole-raw/data.0051.dbl
# Reading Data file : data/hole-raw/data.0052.dbl
# Reading Data file : data/hole-raw/data.0053.dbl
# Reading Data file : data/hole-raw/data.0054.dbl
# Reading Data file : data/hole-raw/data.0055.dbl
# Reading Data file : data/hole-raw/data.0056.dbl
# Reading Data file : data/hole-raw/data.0057.dbl
# Reading Data file : data/hole-raw/data.0058.dbl
# Reading Data file : data/hole-raw/data.0059.dbl
# Reading Data file : data/hole-raw/data.0060.dbl
# Reading Data file : data/hole-raw/data.0061.dbl
# Reading Data file : data/hole-raw/data.0062.dbl
# Reading Data file : data/hole-raw/data.0063.dbl
# Reading Data file : data/hole-raw/data.0064.dbl
# Reading Data file : data/hole-raw/data.0065.dbl
# Reading Data file : data/hole-raw/data.0066.dbl
# Reading Data file : data/hole-raw/data.0067.dbl
# Reading Data file : data/hole-raw/data.0068.dbl
# Reading Data file : data/hole-raw/data.0069.dbl
# Reading Data file : data/hole-raw/data.0070.dbl
# Reading Data file : data/hole-raw/data.0071.dbl
# Reading Data file : data/hole-raw/data.0072.dbl
# Reading Data file : data/hole-raw/data.0073.dbl
# Reading Data file : data/hole-raw/data.0074.dbl
# Reading Data file : data/hole-raw/data.0075.dbl
# Reading Data file : data/hole-raw/data.0076.dbl
# Reading Data file : data/hole-raw/data.0077.dbl
# Reading Data file : data/hole-raw/data.0078.dbl
# Reading Data file : data/hole-raw/data.0079.dbl
# Reading Data file : data/hole-raw/data.0080.dbl
# Reading Data file : data/hole-raw/data.0081.dbl
# Reading Data file : data/hole-raw/data.0082.dbl
# Reading Data file : data/hole-raw/data.0083.dbl
# Reading Data file : data/hole-raw/data.0084.dbl
# Reading Data file : data/hole-raw/data.0085.dbl
# Reading Data file : data/hole-raw/data.0086.dbl
# Reading Data file : data/hole-raw/data.0087.dbl
# Reading Data file : data/hole-raw/data.0088.dbl
# Reading Data file : data/hole-raw/data.0089.dbl
# Reading Data file : data/hole-raw/data.0090.dbl
# Reading Data file : data/hole-raw/data.0091.dbl
# Reading Data file : data/hole-raw/data.0092.dbl
# Reading Data file : data/hole-raw/data.0093.dbl
# Reading Data file : data/hole-raw/data.0094.dbl
# Reading Data file : data/hole-raw/data.0095.dbl
# Reading Data file : data/hole-raw/data.0096.dbl
# Reading Data file : data/hole-raw/data.0097.dbl
# Reading Data file : data/hole-raw/data.0098.dbl
# Reading Data file : data/hole-raw/data.0099.dbl
# Reading Data file : data/hole-raw/data.0100.dbl
# Reading Data file : data/hole-raw/data.0101.dbl
# Reading Data file : data/hole-raw/data.0102.dbl
# Reading Data file : data/hole-raw/data.0103.dbl
# Reading Data file : data/hole-raw/data.0104.dbl
# Reading Data file : data/hole-raw/data.0105.dbl
# Reading Data file : data/hole-raw/data.0106.dbl
# Reading Data file : data/hole-raw/data.0107.dbl
