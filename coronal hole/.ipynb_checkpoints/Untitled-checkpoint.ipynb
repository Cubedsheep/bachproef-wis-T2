# %% [markdown]
# # Data analysis coronal hole model

# %% [markdown]
# ## Import necesarry packages

# %%
import script.pyPLUTO as pp
import matplotlib.pyplot as plt
import matplotlib as mpl

import numpy as np
import pandas as pd
from scipy.ndimage import convolve

# some commonly used constants
CONST_mp = 1.67262171e-24  # gr

# %%
mpl.rcParams["figure.dpi"] = 150    # about the dpi for a 15 inch 1080p laptop, makes sure the displayed plots are the real size 
#mpl.rcParams["figure.dpi"] = 600

mpl.rcParams["figure.figsize"] = (6, 3)
mpl.rcParams["axes.labelsize"] = 20

mpl.rcParams["axes.formatter.limits"] = (-4, 4)

mpl.rcParams["axes.prop_cycle"] = mpl.cycler(color=["xkcd:royal blue", "xkcd:vermillion", "xkcd:orange", 
                                                    "xkcd:magenta", "xkcd:lime", "xkcd:yellow", "grey"])

mpl.rcParams["lines.linewidth"] = 2
mpl.rcParams["axes.linewidth"] = .5

mpl.rcParams["font.size"] = 12

mpl.rcParams["text.usetex"] = True


#mpl.rcParams["figure.facecolor"] = "#fffbf0"
#mpl.rcParams["axes.facecolor"] = "#fffbf0"
#mpl.rcParams["savefig.facecolor"] = '#fffbf0'

# %% [markdown]
# Usefull functions

# %%
def get_extent(file, firstline):
    """this functions retrieves the extent of the grid (in code-units) and number of points from the grid.out 
    file in one dimension (starting at firstline)
    
    file: the grid.out file
    firstline: the line in the file to look for the number of points in that dimension"""
    with open(file, "r") as gridfile:
        lines = gridfile.readlines()
        # get the number of points
        NUM_POINTS = int(lines[firstline])

        # get the extent of the x-axis (in code units)
        # the first line of the grid, so minimum coordinate
        line = lines[firstline+1]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_min = float(parts[1])
        # the last line
        line = lines[firstline+NUM_POINTS]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_max = float(parts[2])
    
    return (NUM_POINTS, (d_min, d_max))

# %% [markdown]
# Import metadata about the output such as the time corresponding to each files and conversion factors from code units to physical units

# %%
# specify the directories where the data is stored and where the output should be stored
DATA_DIR = "data/high-t-res/"
OUT_DIR = "data/images/density/"

# get info about the stored data
file_data = pd.read_csv(DATA_DIR+"dbl.out", sep=" ", names=["index", "t", "dt", "step", "type", "little", "rho",
                                                            "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"])
# delete columns that are not needed
for column in ["index", "type", "little", "rho", "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"]:
    del file_data[column]

# define the conversion factors
UNIT_DENSITY = 1e9*CONST_mp
UNIT_LENGTH = 1e8 # cm
UNIT_VELOCITY = 1e8 # cm/s

X_POINTS = 0
Y_POINTS = 0
X_EXTENT = (0,0)
Y_EXTENT = (0,0)

# get the extend of the grid
# get the extent of the x-axis (in code units)
X_POINTS, X_EXTENT = get_extent(DATA_DIR+"grid.out", 9)
# get the extent of the y-axis
Y_POINTS, Y_EXTENT = get_extent(DATA_DIR+"grid.out", 10+X_POINTS)

# number of files saved
N = len(file_data["t"])

# %% [markdown]
# ## 12 plots of wave interaction

# %%
fig, ax = plt.subplots(4,3,figsize=(6,8))

N = [11*i for i in range(5,17)]

T = file_data["t"].values
extent_temp = X_EXTENT + Y_EXTENT
extent = [value*UNIT_LENGTH for value in extent_temp]
ex = [x*1e-11 for x in extent]

for i in range(12):
    column = i%3
    row = i//3
    axis = ax[row][column]
    
    D = pp.pload(N[i], w_dir=DATA_DIR)
    im=axis.imshow(D.prs, vmin=0.022, vmax=0.033, extent=ex, cmap="plasma")
    
    axis.get_xaxis().set_visible(False)
    axis.get_yaxis().set_visible(False)
    
    axis.set_title("t=%.0f"%T[i])
    
plt.colorbar(im, ax=ax)
    
# switch the axes on the side on
for column in range(3):
    ax[3][column].get_xaxis().set_visible(True)
for row in range(4):
    ax[row][0].get_yaxis().set_visible(True)
    
fig.text(0.5, 0.07, r"distance $[10^{11}cm]$", va='center', ha="center")
fig.text(0.03, 0.5, r"distance $[10^{11}cm]$", va='center', rotation=90)

fig.savefig("../verslag/images/coronal-hole.pdf")
# Out:
# Reading Data file : data/high-t-res/data.0055.dbl
# Reading Data file : data/high-t-res/data.0066.dbl
# Reading Data file : data/high-t-res/data.0077.dbl
# Reading Data file : data/high-t-res/data.0088.dbl
# Reading Data file : data/high-t-res/data.0099.dbl
# Reading Data file : data/high-t-res/data.0110.dbl
# Reading Data file : data/high-t-res/data.0121.dbl
# Reading Data file : data/high-t-res/data.0132.dbl
# Reading Data file : data/high-t-res/data.0143.dbl
# Reading Data file : data/high-t-res/data.0154.dbl
# Reading Data file : data/high-t-res/data.0165.dbl
# Reading Data file : data/high-t-res/data.0176.dbl

# %% [markdown]
# ## Make plots of the density to visualize the wave

# %% [markdown]
# Import for each output file the density, plot it and save the output

# %%
T = file_data["t"].values
extent_temp = X_EXTENT + Y_EXTENT
extent = [value*UNIT_LENGTH for value in extent_temp]

for i in range(N):
    D = pp.pload(i, w_dir=DATA_DIR+"/")
    
    fig, ax = plt.subplots(1,1)
    
    #im=ax.imshow(np.log(plotvar[i]), vmin=np.log(MIN), vmax=np.log(MAX), cmap="plasma")
    im=ax.imshow(D.prs, cmap="plasma", vmin=0.022, vmax=0.033, extent=ex, cmap="plasma")
    cbar = fig.colorbar(im, ax=ax)
    cbar.ax.set_ylabel('density [$g/cm^3$]', rotation=270)
    
    plt.title("time: %.4f s"%(T[i]))
    ax.set_xlabel("x-axis [cm]")
    ax.set_ylabel("y-axis [cm]")
    
    fig.savefig(OUT_DIR+"prs-linear%03i.png"%i)
    
    plt.close(fig=fig)
# Out:
# Reading Data file : data/high-t-res//data.0000.dbl
# Reading Data file : data/high-t-res//data.0001.dbl
# Reading Data file : data/high-t-res//data.0002.dbl
# Reading Data file : data/high-t-res//data.0003.dbl
# Reading Data file : data/high-t-res//data.0004.dbl
# Reading Data file : data/high-t-res//data.0005.dbl
# Reading Data file : data/high-t-res//data.0006.dbl
# Reading Data file : data/high-t-res//data.0007.dbl
# Reading Data file : data/high-t-res//data.0008.dbl
# Reading Data file : data/high-t-res//data.0009.dbl
# Reading Data file : data/high-t-res//data.0010.dbl
# Reading Data file : data/high-t-res//data.0011.dbl
# Reading Data file : data/high-t-res//data.0012.dbl
# Reading Data file : data/high-t-res//data.0013.dbl
# Reading Data file : data/high-t-res//data.0014.dbl
# Reading Data file : data/high-t-res//data.0015.dbl
# Reading Data file : data/high-t-res//data.0016.dbl
# Reading Data file : data/high-t-res//data.0017.dbl
# Reading Data file : data/high-t-res//data.0018.dbl
# Reading Data file : data/high-t-res//data.0019.dbl
# Reading Data file : data/high-t-res//data.0020.dbl
# Reading Data file : data/high-t-res//data.0021.dbl
# Reading Data file : data/high-t-res//data.0022.dbl
# Reading Data file : data/high-t-res//data.0023.dbl
# Reading Data file : data/high-t-res//data.0024.dbl
# Reading Data file : data/high-t-res//data.0025.dbl
# Reading Data file : data/high-t-res//data.0026.dbl
# Reading Data file : data/high-t-res//data.0027.dbl
# Reading Data file : data/high-t-res//data.0028.dbl
# Reading Data file : data/high-t-res//data.0029.dbl
# Reading Data file : data/high-t-res//data.0030.dbl
# Reading Data file : data/high-t-res//data.0031.dbl
# Reading Data file : data/high-t-res//data.0032.dbl
# Reading Data file : data/high-t-res//data.0033.dbl
# Reading Data file : data/high-t-res//data.0034.dbl
# Reading Data file : data/high-t-res//data.0035.dbl
# Reading Data file : data/high-t-res//data.0036.dbl
# Reading Data file : data/high-t-res//data.0037.dbl
# Reading Data file : data/high-t-res//data.0038.dbl
# Reading Data file : data/high-t-res//data.0039.dbl
# Reading Data file : data/high-t-res//data.0040.dbl
# Reading Data file : data/high-t-res//data.0041.dbl
# Reading Data file : data/high-t-res//data.0042.dbl
# Reading Data file : data/high-t-res//data.0043.dbl
# Reading Data file : data/high-t-res//data.0044.dbl
# Reading Data file : data/high-t-res//data.0045.dbl
# Reading Data file : data/high-t-res//data.0046.dbl
# Reading Data file : data/high-t-res//data.0047.dbl
# Reading Data file : data/high-t-res//data.0048.dbl
# Reading Data file : data/high-t-res//data.0049.dbl
# Reading Data file : data/high-t-res//data.0050.dbl
# Reading Data file : data/high-t-res//data.0051.dbl
# Reading Data file : data/high-t-res//data.0052.dbl
# Reading Data file : data/high-t-res//data.0053.dbl
# Reading Data file : data/high-t-res//data.0054.dbl
# Reading Data file : data/high-t-res//data.0055.dbl
# Reading Data file : data/high-t-res//data.0056.dbl
# Reading Data file : data/high-t-res//data.0057.dbl
# Reading Data file : data/high-t-res//data.0058.dbl
# Reading Data file : data/high-t-res//data.0059.dbl
# Reading Data file : data/high-t-res//data.0060.dbl
# Reading Data file : data/high-t-res//data.0061.dbl
# Reading Data file : data/high-t-res//data.0062.dbl
# Reading Data file : data/high-t-res//data.0063.dbl
# Reading Data file : data/high-t-res//data.0064.dbl
# Reading Data file : data/high-t-res//data.0065.dbl
# Reading Data file : data/high-t-res//data.0066.dbl
# Reading Data file : data/high-t-res//data.0067.dbl
# Reading Data file : data/high-t-res//data.0068.dbl
# Reading Data file : data/high-t-res//data.0069.dbl
# Reading Data file : data/high-t-res//data.0070.dbl
# Reading Data file : data/high-t-res//data.0071.dbl
# Reading Data file : data/high-t-res//data.0072.dbl
# Reading Data file : data/high-t-res//data.0073.dbl
# Reading Data file : data/high-t-res//data.0074.dbl
# Reading Data file : data/high-t-res//data.0075.dbl
# Reading Data file : data/high-t-res//data.0076.dbl
# Reading Data file : data/high-t-res//data.0077.dbl
# Reading Data file : data/high-t-res//data.0078.dbl
# Reading Data file : data/high-t-res//data.0079.dbl
# Reading Data file : data/high-t-res//data.0080.dbl
# Reading Data file : data/high-t-res//data.0081.dbl
# Reading Data file : data/high-t-res//data.0082.dbl
# Reading Data file : data/high-t-res//data.0083.dbl
# Reading Data file : data/high-t-res//data.0084.dbl
# Reading Data file : data/high-t-res//data.0085.dbl
# Reading Data file : data/high-t-res//data.0086.dbl
# Reading Data file : data/high-t-res//data.0087.dbl
# Reading Data file : data/high-t-res//data.0088.dbl
# Reading Data file : data/high-t-res//data.0089.dbl
# Reading Data file : data/high-t-res//data.0090.dbl
# Reading Data file : data/high-t-res//data.0091.dbl
# Reading Data file : data/high-t-res//data.0092.dbl
# Reading Data file : data/high-t-res//data.0093.dbl
# Reading Data file : data/high-t-res//data.0094.dbl
# Reading Data file : data/high-t-res//data.0095.dbl
# Reading Data file : data/high-t-res//data.0096.dbl
# Reading Data file : data/high-t-res//data.0097.dbl
# Reading Data file : data/high-t-res//data.0098.dbl
# Reading Data file : data/high-t-res//data.0099.dbl
# Reading Data file : data/high-t-res//data.0100.dbl
# Reading Data file : data/high-t-res//data.0101.dbl
# Reading Data file : data/high-t-res//data.0102.dbl
# Reading Data file : data/high-t-res//data.0103.dbl
# Reading Data file : data/high-t-res//data.0104.dbl
# Reading Data file : data/high-t-res//data.0105.dbl
# Reading Data file : data/high-t-res//data.0106.dbl
# Reading Data file : data/high-t-res//data.0107.dbl
# Reading Data file : data/high-t-res//data.0108.dbl
# Reading Data file : data/high-t-res//data.0109.dbl
# Reading Data file : data/high-t-res//data.0110.dbl
# Reading Data file : data/high-t-res//data.0111.dbl
# Reading Data file : data/high-t-res//data.0112.dbl
# Reading Data file : data/high-t-res//data.0113.dbl
# Reading Data file : data/high-t-res//data.0114.dbl
# Reading Data file : data/high-t-res//data.0115.dbl
# Reading Data file : data/high-t-res//data.0116.dbl
# Reading Data file : data/high-t-res//data.0117.dbl
# Reading Data file : data/high-t-res//data.0118.dbl
# Reading Data file : data/high-t-res//data.0119.dbl
# Reading Data file : data/high-t-res//data.0120.dbl
# Reading Data file : data/high-t-res//data.0121.dbl
# Reading Data file : data/high-t-res//data.0122.dbl
# Reading Data file : data/high-t-res//data.0123.dbl
# Reading Data file : data/high-t-res//data.0124.dbl
# Reading Data file : data/high-t-res//data.0125.dbl
# Reading Data file : data/high-t-res//data.0126.dbl
# Reading Data file : data/high-t-res//data.0127.dbl
# Reading Data file : data/high-t-res//data.0128.dbl
# Reading Data file : data/high-t-res//data.0129.dbl
# Reading Data file : data/high-t-res//data.0130.dbl
# Reading Data file : data/high-t-res//data.0131.dbl
# Reading Data file : data/high-t-res//data.0132.dbl
# Reading Data file : data/high-t-res//data.0133.dbl
# Reading Data file : data/high-t-res//data.0134.dbl
# Reading Data file : data/high-t-res//data.0135.dbl
# Reading Data file : data/high-t-res//data.0136.dbl
# Reading Data file : data/high-t-res//data.0137.dbl
# Reading Data file : data/high-t-res//data.0138.dbl
# Reading Data file : data/high-t-res//data.0139.dbl
# Reading Data file : data/high-t-res//data.0140.dbl
# Reading Data file : data/high-t-res//data.0141.dbl
# Reading Data file : data/high-t-res//data.0142.dbl
# Reading Data file : data/high-t-res//data.0143.dbl
# Reading Data file : data/high-t-res//data.0144.dbl
# Reading Data file : data/high-t-res//data.0145.dbl
# Reading Data file : data/high-t-res//data.0146.dbl
# Reading Data file : data/high-t-res//data.0147.dbl
# Reading Data file : data/high-t-res//data.0148.dbl
# Reading Data file : data/high-t-res//data.0149.dbl
# Reading Data file : data/high-t-res//data.0150.dbl
# Reading Data file : data/high-t-res//data.0151.dbl
# Reading Data file : data/high-t-res//data.0152.dbl
# Reading Data file : data/high-t-res//data.0153.dbl
# Reading Data file : data/high-t-res//data.0154.dbl
# Reading Data file : data/high-t-res//data.0155.dbl
# Reading Data file : data/high-t-res//data.0156.dbl
# Reading Data file : data/high-t-res//data.0157.dbl
# Reading Data file : data/high-t-res//data.0158.dbl
# Reading Data file : data/high-t-res//data.0159.dbl
# Reading Data file : data/high-t-res//data.0160.dbl
# Reading Data file : data/high-t-res//data.0161.dbl
# Reading Data file : data/high-t-res//data.0162.dbl
# Reading Data file : data/high-t-res//data.0163.dbl
# Reading Data file : data/high-t-res//data.0164.dbl
# Reading Data file : data/high-t-res//data.0165.dbl
# Reading Data file : data/high-t-res//data.0166.dbl
# Reading Data file : data/high-t-res//data.0167.dbl
# Reading Data file : data/high-t-res//data.0168.dbl
# Reading Data file : data/high-t-res//data.0169.dbl
# Reading Data file : data/high-t-res//data.0170.dbl
# Reading Data file : data/high-t-res//data.0171.dbl
# Reading Data file : data/high-t-res//data.0172.dbl
# Reading Data file : data/high-t-res//data.0173.dbl
# Reading Data file : data/high-t-res//data.0174.dbl
# Reading Data file : data/high-t-res//data.0175.dbl
# Reading Data file : data/high-t-res//data.0176.dbl
# Reading Data file : data/high-t-res//data.0177.dbl
# Reading Data file : data/high-t-res//data.0178.dbl
# Reading Data file : data/high-t-res//data.0179.dbl
# Reading Data file : data/high-t-res//data.0180.dbl
# Reading Data file : data/high-t-res//data.0181.dbl
# Reading Data file : data/high-t-res//data.0182.dbl
# Reading Data file : data/high-t-res//data.0183.dbl
# Reading Data file : data/high-t-res//data.0184.dbl
# Reading Data file : data/high-t-res//data.0185.dbl
# Reading Data file : data/high-t-res//data.0186.dbl
# Reading Data file : data/high-t-res//data.0187.dbl
# Reading Data file : data/high-t-res//data.0188.dbl
# Reading Data file : data/high-t-res//data.0189.dbl
# Reading Data file : data/high-t-res//data.0190.dbl
# Reading Data file : data/high-t-res//data.0191.dbl
# Reading Data file : data/high-t-res//data.0192.dbl
# Reading Data file : data/high-t-res//data.0193.dbl
# Reading Data file : data/high-t-res//data.0194.dbl
# Reading Data file : data/high-t-res//data.0195.dbl
# Reading Data file : data/high-t-res//data.0196.dbl
# Reading Data file : data/high-t-res//data.0197.dbl
# Reading Data file : data/high-t-res//data.0198.dbl
# Reading Data file : data/high-t-res//data.0199.dbl
# Reading Data file : data/high-t-res//data.0200.dbl
