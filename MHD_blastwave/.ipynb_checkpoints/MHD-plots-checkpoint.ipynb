# %% [markdown]
# # Plotting of MHD data

# %%
import script.pyPLUTO as pp
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.image import imread

import numpy as np
import pandas as pd

# some commonly used constants
CONST_mp = 1.67262171e-24  # gr

# %% [markdown]
# Increase rsolution of plots

# %%
mpl.rcParams["figure.dpi"] = 150    # about the dpi for a 15 inch 1080p laptop, makes sure the displayed plots are the real size 
#mpl.rcParams["figure.dpi"] = 600

mpl.rcParams["figure.figsize"] = (6, 3.5)
mpl.rcParams["axes.labelsize"] = 20

mpl.rcParams["axes.formatter.limits"] = (-4, 4)

mpl.rcParams["axes.prop_cycle"] = mpl.cycler(color=["xkcd:royal blue", "xkcd:vermillion", "xkcd:lime",
                                  "xkcd:yellow", "xkcd:orange", "xkcd:magenta", "grey"])

mpl.rcParams["lines.linewidth"] = 2
mpl.rcParams["axes.linewidth"] = .5

mpl.rcParams["font.size"] = 12

mpl.rcParams["text.usetex"] = True


#mpl.rcParams["figure.facecolor"] = "#fffbf0"
#mpl.rcParams["axes.facecolor"] = "#fffbf0"
#mpl.rcParams["savefig.facecolor"] = '#fffbf0'

# %% [markdown]
# Usefull functions

# %%
def get_extent(file, firstline):
    """this functions retrieves the extent of the grid (in code-units) and number of points from the grid.out 
    file in one dimension (starting at firstline)
    
    file: the grid.out file
    firstline: the line in the file to look for the number of points in that dimension"""
    with open(file, "r") as gridfile:
        lines = gridfile.readlines()
        # get the number of points
        NUM_POINTS = int(lines[firstline])

        # get the extent of the x-axis (in code units)
        # the first line of the grid, so minimum coordinate
        line = lines[firstline+1]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_min = float(parts[1])
        # the last line
        line = lines[firstline+NUM_POINTS]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_max = float(parts[2])
    
    return (NUM_POINTS, (d_min, d_max))

# %% [markdown]
# ## get metadata of the simulation data

# %%
# specify the directories where the data is stored and where the output should be stored
DATA_DIR = "out-raw-Buniform/low-beta05/"
OUT_DIR = "images/"

# define the conversion factors, can be seen when starting the simulation
UNIT_DENSITY = 1e9*CONST_mp
UNIT_LENGTH = 1e8 # cm (1AU)
UNIT_VELOCITY = 1e8 # cm/s
UNIT_TIME = UNIT_LENGTH/UNIT_VELOCITY
UNIT_PRESSURE = 1.673e1   # dyne/cm^2

# %%
# get info about the stored data
file_data = pd.read_csv(DATA_DIR+"dbl.out", sep=" ", names=["index", "t", "dt", "step", "type", "little", "rho",
                                                            "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"])
# delete columns that are not needed
for column in ["index", "type", "little", "rho", "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"]:
    del file_data[column]

X_POINTS = 0
Y_POINTS = 0
X_EXTENT = (0,0)
Y_EXTENT = (0,0)

# get the extend of the grid
# get the extent of the x-axis (in code units)
X_POINTS, X_EXTENT = get_extent(DATA_DIR+"grid.out", 9)
# get the extent of the y-axis
Y_POINTS, Y_EXTENT = get_extent(DATA_DIR+"grid.out", 10+X_POINTS)

# number of files saved
N = len(file_data["t"])

# physical extent of the grid
extent_temp = X_EXTENT + Y_EXTENT
extent = [value*UNIT_LENGTH for value in extent_temp]
# physical time data
T = file_data["t"].values*UNIT_TIME

# %% [markdown]
# Names of all directories containing data, with extra info about beta and pressure

# %%
sims = [
    {"directory":"beta01/", "beta":0.1, "low":False},
    {"directory":"beta05/", "beta":0.5, "low":False},
    {"directory":"beta1/", "beta":1, "low":False},
    {"directory":"beta10/", "beta":10, "low":False},
    {"directory":"low-beta01/", "beta":0.1, "low":True},
    {"directory":"low-beta05/", "beta":0.5, "low":True},
    {"directory":"low-beta1/", "beta":1, "low":True},
    {"directory":"low-beta10/", "beta":10, "low":True},
]

# %% [markdown]
# ## Combined plots

# %%
for n in range(29,N+1):
    fig, ax = plt.subplots(2,4, figsize=(6,4))

    prs_array = []
    min_prs = [1,1]
    max_prs = [1,1]

    ex = [x*1e-8 for x in extent]

    # simulations with high pressure
    for i in range(4):
        DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
        D = pp.pload(n, w_dir=DATA_DIR+"/")
        var = D.prs
        prs_array.append(var)
        # find the min and max pressure
        if (m := np.min(var)) < min_prs[0]:
            min_prs[0] = m
        if (m := np.max(var)) > max_prs[0]:
            max_prs[0] = m
        del D

    print(min_prs[0],max_prs[0])

    # simulations with low pressure
    for i in range(4,8):
        DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
        D = pp.pload(n, w_dir=DATA_DIR+"/")
        var = D.prs

        prs_array.append(var)
        # find the min and max pressure
        if (m := np.min(var)) < min_prs[1]:
            min_prs[1] = m
        if (m := np.max(var)) > max_prs[1]:
            max_prs[1] = m
        del D

    for i in range(8):
        m = min_prs[i//4]
        M = max_prs[i//4]
        row = i//4
        column = i%4
        axis = ax[row][column]
        # prevent clutter
        ax[row][column].get_xaxis().set_visible(False)
        ax[row][column].get_yaxis().set_visible(False)
        im = ax[row][column].imshow(prs_array[i]*UNIT_PRESSURE, vmin=m*UNIT_PRESSURE, 
                            vmax=M*UNIT_PRESSURE, cmap="plasma", extent=ex)
        if sims[i]["low"] and i//4==0:
            ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])
        elif i//4==0:
            ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])

        if i%4==3:
            cbar = fig.colorbar(im, ax=axis, fraction=0.046, pad=0.02)


    # axis labels
    fig.text(0.5, 0.03, r"distance $[10^8cm]$", va='center')
    fig.text(0.02, 0.45, r"distance $[10^8cm]$", va='center', rotation=90)
    fig.text(0.96, 0.57, r"pressure $[dyne/cm^2]$", va="center", rotation=270)

    # switch the axes on the side on
    for column in range(4):
        ax[1][column].get_xaxis().set_visible(True)
    for row in range(2):
        ax[row][0].get_yaxis().set_visible(True)

    del prs_array


    fig.suptitle("time: %.2e s" %T[n], y=0.98)    

    plt.tight_layout()

    fig.savefig("out-image/combined/pressure-%02d.png" %n, dpi=300)
    plt.close(fig=fig)
# Out:
# Reading Data file : out-raw-Buniform/beta01//data.0029.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0029.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0029.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0029.dbl
# 0.7703277319235516 2.126568056510917
# Reading Data file : out-raw-Buniform/low-beta01//data.0029.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0029.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0029.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0029.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0030.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0030.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0030.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0030.dbl
# 0.7773619419553184 2.1052178312178884
# Reading Data file : out-raw-Buniform/low-beta01//data.0030.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0030.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0030.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0030.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0031.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0031.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0031.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0031.dbl
# 0.7791954606100071 2.0844365430756997
# Reading Data file : out-raw-Buniform/low-beta01//data.0031.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0031.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0031.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0031.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0032.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0032.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0032.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0032.dbl
# 0.77814816333677 2.064526197040406
# Reading Data file : out-raw-Buniform/low-beta01//data.0032.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0032.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0032.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0032.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0033.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0033.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0033.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0033.dbl
# 0.7796481845894131 2.0454150662994586
# Reading Data file : out-raw-Buniform/low-beta01//data.0033.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0033.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0033.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0033.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0034.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0034.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0034.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0034.dbl
# 0.7800773935406005 2.027649473415184
# Reading Data file : out-raw-Buniform/low-beta01//data.0034.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0034.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0034.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0034.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0035.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0035.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0035.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0035.dbl
# 0.7815806889595134 2.010311040179879
# Reading Data file : out-raw-Buniform/low-beta01//data.0035.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0035.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0035.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0035.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0036.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0036.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0036.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0036.dbl
# 0.783905623932043 1.9934736019710906
# Reading Data file : out-raw-Buniform/low-beta01//data.0036.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0036.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0036.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0036.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0037.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0037.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0037.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0037.dbl
# 0.7867118658959652 1.977816826867979
# Reading Data file : out-raw-Buniform/low-beta01//data.0037.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0037.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0037.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0037.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0038.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0038.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0038.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0038.dbl
# 0.7892356702237016 1.9623126542891918
# Reading Data file : out-raw-Buniform/low-beta01//data.0038.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0038.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0038.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0038.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0039.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0039.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0039.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0039.dbl
# 0.788148651558997 1.9477642802925688
# Reading Data file : out-raw-Buniform/low-beta01//data.0039.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0039.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0039.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0039.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0040.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0040.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0040.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0040.dbl
# 0.7894724520217499 1.933352629624914
# Reading Data file : out-raw-Buniform/low-beta01//data.0040.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0040.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0040.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0040.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0041.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0041.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0041.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0041.dbl
# 0.7904582808197586 1.9197843635242335
# Reading Data file : out-raw-Buniform/low-beta01//data.0041.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0041.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0041.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0041.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0042.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0042.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0042.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0042.dbl
# 0.7913524881224668 1.9065757459414931
# Reading Data file : out-raw-Buniform/low-beta01//data.0042.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0042.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0042.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0042.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0043.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0043.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0043.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0043.dbl
# 0.7922447351095249 1.893821602669594
# Reading Data file : out-raw-Buniform/low-beta01//data.0043.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0043.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0043.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0043.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0044.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0044.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0044.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0044.dbl
# 0.7934755791079314 1.8814130389764971
# Reading Data file : out-raw-Buniform/low-beta01//data.0044.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0044.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0044.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0044.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0045.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0045.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0045.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0045.dbl
# 0.7944656798607735 1.8697607361305806
# Reading Data file : out-raw-Buniform/low-beta01//data.0045.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0045.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0045.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0045.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0046.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0046.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0046.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0046.dbl
# 0.7960253333359756 1.8580322018936444
# Reading Data file : out-raw-Buniform/low-beta01//data.0046.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0046.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0046.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0046.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0047.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0047.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0047.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0047.dbl
# 0.7981952997521946 1.8470442781055674
# Reading Data file : out-raw-Buniform/low-beta01//data.0047.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0047.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0047.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0047.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0048.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0048.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0048.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0048.dbl
# 0.8008793172730859 1.8363624299126327
# Reading Data file : out-raw-Buniform/low-beta01//data.0048.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0048.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0048.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0048.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0049.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0049.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0049.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0049.dbl
# 0.8017006457581858 1.8256894572166358
# Reading Data file : out-raw-Buniform/low-beta01//data.0049.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0049.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0049.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0049.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0050.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0050.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0050.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0050.dbl
# 0.8010455830624028 1.8156339573400173
# Reading Data file : out-raw-Buniform/low-beta01//data.0050.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0050.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0050.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0050.dbl
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-4352454554b4> in <module>
#      11     for i in range(4):
#      12         DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
# ---> 13         D = pp.pload(n, w_dir=DATA_DIR+"/")
#      14         var = D.prs
#      15         prs_array.append(var)
#
# ~/Documents/Data/studie/3e bach - sem 2/bachproef-wis-T2/MHD_blastwave/script/pyPLUTO.py in __init__(self, ns, w_dir, datatype, level, x1range, x2range, x3range)
#     141         self.wdir = w_dir
#     142
# --> 143         Data_dictionary = self.ReadDataFile(self.NStepStr)
#     144         for keys in Data_dictionary:
#     145             object.__setattr__(self, keys, Data_dictionary.get(keys))
#
# ~/Documents/Data/studie/3e bach - sem 2/bachproef-wis-T2/MHD_blastwave/script/pyPLUTO.py in ReadDataFile(self, num)
#     709         self.ReadVarFile(varfile)
#     710         self.ReadGridFile(gridfile)
# --> 711         self.ReadTimeInfo(varfile)
#     712         nstr = num
#     713         if self.endianess == 'big':
#
# ~/Documents/Data/studie/3e bach - sem 2/bachproef-wis-T2/MHD_blastwave/script/pyPLUTO.py in ReadTimeInfo(self, timefile)
#     165             for line in f_var.readlines():
#     166                 tlist.append(line.split())
# --> 167             self.SimTime = float(tlist[ns][1])
#     168             self.Dt = float(tlist[ns][2])
#     169
#
# IndexError: list index out of range

# %% [markdown]
# ### Group speed MHD waves

# %% [markdown]
# formulas for the phase speed

# %%
def phase_fast(va, vs, theta):
    return np.sqrt(1/2*(va**2+vs**2 + np.sqrt((va**2+vs**2)**2-4*va**2*vs**2*np.cos(theta)**2)))

def phase_slow(va, vs, theta):
    return np.sqrt(1/2*(va**2+vs**2 - np.sqrt((va**2+vs**2)**2-4*va**2*vs**2*np.cos(theta)**2)))

def phase_alfven(va, theta):
    return va*np.cos(theta)

# %%
def group_fast(va, vs, theta, e, z):
    vp = phase_fast(va,vs,theta)
    return (vp**4*e - vs**2*va**2*z*np.cos(theta)) / (vp*(2*vp**2-(vs**2+va**2)))

def group_slow(va, vs, theta, e, z):
    vp = phase_slow(va,vs,theta)
    return (vp**4*e - vs**2*va**2*z*np.cos(theta)) / (vp*(2*vp**2-(vs**2+va**2)))

# %% [markdown]
# ### pressure imshow with group speed overlay

# %% [markdown]
# first 4 plots

# %%
n = 25

fig, ax = plt.subplots(2,2, figsize=(6,5.5))

prs_array = []
min_prs = [1,1]
max_prs = [1,1]

# initialization for plot group speed
THETA = np.linspace(0,2*np.pi,400)
z = np.array([1,0])
E = np.array([[np.cos(theta), np.sin(theta)] for theta in THETA])
speed_multiplier = {True : 1.2, False : 1.5}
v0 = 1

ex = [x*1e-8 for x in extent]

# simulations with high pressure
for i in range(2):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs
    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[0]:
        min_prs[0] = m
    if (m := np.max(var)) > max_prs[0]:
        max_prs[0] = m
    del D


# simulations with low pressure
for i in range(4,6):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs

    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[1]:
        min_prs[1] = m
    if (m := np.max(var)) > max_prs[1]:
        max_prs[1] = m
    del D

for i in range(4):
    # initializations
    m = min_prs[i//2]
    M = max_prs[i//2]
    row = i//2
    column = i%2
    axis = ax[row][column]
    # prevent clutter
    axis.get_xaxis().set_visible(False)
    axis.get_yaxis().set_visible(False)
    im = axis.imshow(prs_array[i]*UNIT_PRESSURE, vmin=m*UNIT_PRESSURE, 
                        vmax=M*UNIT_PRESSURE, cmap="plasma", extent=ex)
    # plot the pressure map
    if sims[i]["low"] and i//2==0:
        axis.set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    elif i//2==0:
        axis.set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    # colorbar on the side
    if i%2==1:
        cbar = fig.colorbar(im, ax=axis, fraction=0.046, pad=0.02)
    # plot the theoretical group speed
    beta = sims[i]["beta"]
    va = np.sqrt(1/(beta))*v0
    vs = np.sqrt(gamma)*v0
    vgf = np.array([group_fast(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])*T[n]*speed_multiplier[sims[i]["low"]]
    vgs = np.array([group_slow(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])*T[n]*speed_multiplier[sims[i]["low"]]
    
    # fast mode
    axis.plot(vgf[:,0], vgf[:,1], "--w", lw=0.75)
    # slow mode
    axis.plot(vgs[0:100,0], vgs[0:100,1], "-k", lw=0.75)
    axis.plot(vgs[101:300,0], vgs[101:300,1], "-k", lw=0.75)
    axis.plot(vgs[301:400,0], vgs[301:400,1], "-k", lw=0.75)


# axis labels
fig.text(0.5, 0.03, r"distance $[10^8cm]$", va='center')
fig.text(0.02, 0.45, r"distance $[10^8cm]$", va='center', rotation=90)
fig.text(0.96, 0.57, r"pressure $[dyne/cm^2]$", va="center", rotation=270)

# switch the axes on the side on
for column in range(2):
    ax[1][column].get_xaxis().set_visible(True)
for row in range(2):
    ax[row][0].get_yaxis().set_visible(True)

del prs_array


fig.suptitle("time: %.2e s" %T[n], y=0.98)    

plt.tight_layout()

fig.savefig("../verslag/images/group-speed-pressure.png")
# Out:
# Reading Data file : out-raw-Buniform/beta01//data.0025.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0025.dbl
# Reading Data file : out-raw-Buniform/low-beta01//data.0025.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0025.dbl

# %% [markdown]
# last 4 plots

# %%
n = 25

fig, ax = plt.subplots(2,4, figsize=(6,4))

prs_array = []
min_prs = [1,1]
max_prs = [1,1]

# initialization for plot group speed
THETA = np.linspace(0,2*np.pi,400)
z = np.array([1,0])
E = np.array([[np.cos(theta), np.sin(theta)] for theta in THETA])
speed_multiplier = {True : 1.2, False : 1.5}
v0 = 1

ex = [x*1e-8 for x in extent]

# simulations with high pressure
for i in range(4):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs
    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[0]:
        min_prs[0] = m
    if (m := np.max(var)) > max_prs[0]:
        max_prs[0] = m
    del D


# simulations with low pressure
for i in range(4,8):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs

    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[1]:
        min_prs[1] = m
    if (m := np.max(var)) > max_prs[1]:
        max_prs[1] = m
    del D

for i in range(8):
    # initializations
    m = min_prs[i//4]
    M = max_prs[i//4]
    row = i//4
    column = i%4
    axis = ax[row][column]
    # prevent clutter
    axis.get_xaxis().set_visible(False)
    axis.get_yaxis().set_visible(False)
    im = axis.imshow(prs_array[i]*UNIT_PRESSURE, vmin=m*UNIT_PRESSURE, 
                        vmax=M*UNIT_PRESSURE, cmap="plasma", extent=ex)
    # plot the pressure map
    if sims[i]["low"] and i//4==0:
        axis.set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    elif i//4==0:
        axis.set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    # colorbar on the side
    if i%4==3:
        cbar = fig.colorbar(im, ax=axis, fraction=0.046, pad=0.02)
    # plot the theoretical group speed
    beta = sims[i]["beta"]
    va = np.sqrt(1/(beta))*v0
    vs = np.sqrt(gamma)*v0
    vgf = np.array([group_fast(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])*T[n]*speed_multiplier[sims[i]["low"]]
    vgs = np.array([group_slow(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])*T[n]*speed_multiplier[sims[i]["low"]]
    
    # fast mode
    axis.plot(vgf[:,0], vgf[:,1], "--w", lw=0.75)
    # slow mode
    axis.plot(vgs[0:100,0], vgs[0:100,1], "-k", lw=0.75)
    axis.plot(vgs[101:300,0], vgs[101:300,1], "-k", lw=0.75)
    axis.plot(vgs[301:400,0], vgs[301:400,1], "-k", lw=0.75)


# axis labels
fig.text(0.5, 0.03, r"distance $[10^8cm]$", va='center')
fig.text(0.02, 0.45, r"distance $[10^8cm]$", va='center', rotation=90)
fig.text(0.96, 0.57, r"pressure $[dyne/cm^2]$", va="center", rotation=270)

# switch the axes on the side on
for column in range(4):
    ax[1][column].get_xaxis().set_visible(True)
for row in range(2):
    ax[row][0].get_yaxis().set_visible(True)

del prs_array


fig.suptitle("time: %.2e s" %T[n], y=0.98)    

plt.tight_layout()

fig.savefig("../verslag/images/group-speed-pressure.png")
# Out:
# Reading Data file : out-raw-Buniform/beta01//data.0025.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0025.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0025.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0025.dbl
# Reading Data file : out-raw-Buniform/low-beta01//data.0025.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0025.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0025.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0025.dbl

# %% [markdown]
# ### Group speed diagrams

# %%
fig, ax = plt.subplots(2,2, figsize=(6,5.5))

z = np.array([1,0])
THETA = np.linspace(0,2*np.pi,4000)
E = np.array([[np.cos(theta), np.sin(theta)] for theta in THETA])
v0 = 1

beta_arr = [0.1, 0.5, 1, 10]

# lay-out parameters
lw=1

for i in range(4):
    axis = ax[i//2][i%2]
    beta = beta_arr[i]
    va = np.sqrt(1/(beta))*v0
    vs = np.sqrt(gamma)*v0
    # calculate the group speeds
    vgf = np.array([group_fast(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])
    vgs = np.array([group_slow(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])
    # plot fast mode
    axis.plot(vgf[:,0], vgf[:,1],lw=lw)
    # plot slow mode
    axis.plot(vgs[0:1000,0], vgs[0:1000,1], color="xkcd:vermillion", lw=lw)
    axis.plot(vgs[1001:3000,0], vgs[1001:3000,1], color="xkcd:vermillion",lw=lw)
    axis.plot(vgs[3001:4000,0], vgs[3001:4000,1], color="xkcd:vermillion",lw=lw)
    axis.set_aspect("equal")
    # axes through the origin
    axis.spines["left"].set_position("zero")
    axis.spines["bottom"].set_position("zero")
    axis.spines["top"].set_color("none")
    axis.spines["right"].set_color("none")
    # custom axis labels
    axis.set_xticks([-vs, +vs, -va, va])
    axis.set_xticklabels([r"$-v_s$", r"$v_s$", r"$-v_a$", r"$v_a$"])
    axis.set_yticks([-vs, +vs, -va, va])
    axis.set_yticklabels([r"$-v_s$", r"$v_s$", r"$-v_a$", r"$v_a$"])
    # axis title
    axis.set_title(r"$\beta=%.1f$"%beta, size=12)
    
plt.suptitle(r"Group speed of MHD waves for different values of $\beta$")
plt.show()

fig.savefig("../verslag/images/MHD-group-speed.png")

# %% [markdown]
# ## experimenteren lay-out plots

# %% [markdown]
# plot of phase speed

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')

beta = 0.774
gamma = 5/3
va = np.sqrt(1/(beta))*v0
vs = np.sqrt(gamma)*v0

va = 1
vs = np.sqrt(beta/gamma)*va

THETA = np.linspace(0,2*np.pi,400)
ax.plot(THETA, phase_fast(va,vs,THETA))
ax.plot(THETA, phase_slow(va,vs,THETA))
ax.plot(THETA, np.abs(phase_alfven(va, THETA)))

# %% [markdown]
# Group speed Michaël manier

# %% [markdown]
# ```
# def group_fast(va, vs, theta, k):
#     t = np.array([-k[1], k[0]])
#     vp = phase_fast(va,vs,theta)
#     return vp*k + va**2*vs**2*np.cos(theta)*np.sin(theta)*t/(vp*np.sqrt((va**2+vs**2)**2-4*va**2*vs**2*np.cos(theta)**2))
#
# def group_slow(va, vs, theta, k):
#     t = np.array([-k[1], k[0]])
#     vp = phase_slow(va,vs,theta)
#     return vp*k - va**2*vs**2*np.cos(theta)*np.sin(theta)*t/(vp*np.sqrt((va**2+vs**2)**2-4*va**2*vs**2*np.cos(theta)**2))
#   ```

# %%
z = np.array([1,0])
E = np.array([[np.cos(theta), np.sin(theta)] for theta in THETA])

v0 = 1
beta = 0.774
va = np.sqrt(1/(beta))*v0
vs = np.sqrt(gamma)*v0

vgf = np.array([group_fast(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])
vgs = np.array([group_slow(va, vs, THETA[i], E[i], z) for i in range(len(THETA))])

fig, ax = plt.subplots(1,1)

ax.plot(vgf[:,0], vgf[:,1])
ax.plot(vgs[0:100,0], vgs[0:100,1], color="xkcd:vermillion")
ax.plot(vgs[101:300,0], vgs[101:300,1], color="xkcd:vermillion")
ax.plot(vgs[301:400,0], vgs[301:400,1], color="xkcd:vermillion")
ax.set_aspect("equal")

# %%
n = 15

fig, ax = plt.subplots(2,4, figsize=(6,4))

prs_array = []
min_prs = [1,1]
max_prs = [1,1]

ex = [x*1e-8 for x in extent]

# simulations with high pressure
for i in range(4):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs
    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[0]:
        min_prs[0] = m
    if (m := np.max(var)) > max_prs[0]:
        max_prs[0] = m
    del D

print(min_prs[0],max_prs[0])
    
# simulations with low pressure
for i in range(4,8):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs
    
    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[1]:
        min_prs[1] = m
    if (m := np.max(var)) > max_prs[1]:
        max_prs[1] = m
    del D

for i in range(8):
    m = min_prs[i//4]
    M = max_prs[i//4]
    row = i//4
    column = i%4
    axis = ax[row][column]
    # prevent clutter
    ax[row][column].get_xaxis().set_visible(False)
    ax[row][column].get_yaxis().set_visible(False)
    im = ax[row][column].imshow(prs_array[i]*UNIT_PRESSURE, vmin=m*UNIT_PRESSURE, 
                        vmax=M*UNIT_PRESSURE, cmap="plasma", extent=ex)
    if sims[i]["low"] and i//4==0:
        ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    elif i//4==0:
        ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    
    if i%4==3:
        cbar = fig.colorbar(im, ax=axis, fraction=0.046, pad=0.02)
    

# axis labels
fig.text(0.5, 0.03, r"distance $[10^8cm]$", va='center')
fig.text(0.02, 0.45, r"distance $[10^8cm]$", va='center', rotation=90)
fig.text(0.96, 0.57, r"pressure $[dyne/cm^2]$", va="center", rotation=270)

# switch the axes on the side on
for column in range(4):
    ax[1][column].get_xaxis().set_visible(True)
for row in range(2):
    ax[row][0].get_yaxis().set_visible(True)

del prs_array


fig.suptitle("time: %.2e s" %T[n], y=0.98)    

plt.tight_layout()

#fig.savefig("out-image/combined/pressure-%02d.png" %n, dpi=300)
#plt.close(fig=fig)
plt.show()
# Out:
# Reading Data file : out-raw-Buniform/beta01//data.0015.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0015.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0015.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0015.dbl
# 0.7611382355351661 2.5513093773882822
# Reading Data file : out-raw-Buniform/low-beta01//data.0015.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0015.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0015.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0015.dbl

# %% [markdown]
# ## Individual plots

# %%
sim = sims[5]
n = 14

D = pp.pload(n, w_dir="out-raw/"+sim["directory"])

fig, ax = plt.subplots(1,1)

##im=ax.imshow(np.log(plotvar[i]), vmin=np.log(MIN), vmax=np.log(MAX), cmap="plasma")
##im=ax.imshow(D.prs, cmap="plasma", extent=extent, vmin=8, vmax=16)
im=ax.imshow(D.Bx1*UNIT_PRESSURE, cmap="viridis", extent=extent)
cbar = fig.colorbar(im, ax=ax)
cbar.ax.set_ylabel('pressure [$dyne/cm^2$]', rotation=270, labelpad=15.0)


### streamlines for magnetic field
side = np.linspace(extent[0], extent[1], 1024)
X, Y = np.meshgrid(side, side)
#ax.streamplot(X, Y, D.Bx1, D.Bx2, maxlength=2000, linewidth=1, 
#              color=np.sqrt(D.Bx1**2+D.Bx2**2), 
#              density=4, arrowsize=0, cmap="winter")

if sim["low"]:
    plt.title(r"low pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"],T [n]), pad=15.0)
else:
    plt.title(r"high pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"], T[n]), pad=15.0)
ax.set_xlabel("x-axis [cm]")
ax.set_ylabel("y-axis [cm]")
# Out:
# Reading Data file : out-raw/low-beta05/data.0014.dbl
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-b7e2f59b0969> in <module>
#      21
#      22 if sim["low"]:
# ---> 23     plt.title(r"low pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"],T [n]), pad=15.0)
#      24 else:
#      25     plt.title(r"high pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"], T[n]), pad=15.0)
#
# IndexError: index 14 is out of bounds for axis 0 with size 11

# %%
img = imread('test-image.png')

plt.imshow(img)
