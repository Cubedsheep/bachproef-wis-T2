# %% [markdown]
# # Plotting of MHD data

# %%
import script.pyPLUTO as pp
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.image import imread

import numpy as np
import pandas as pd

# some commonly used constants
CONST_mp = 1.67262171e-24  # gr

# %% [markdown]
# Increase rsolution of plots

# %%
mpl.rcParams["figure.dpi"] = 150    # about the dpi for a 15 inch 1080p laptop, makes sure the displayed plots are the real size 
#mpl.rcParams["figure.dpi"] = 600

mpl.rcParams["figure.figsize"] = (6, 3.5)
mpl.rcParams["axes.labelsize"] = 20

mpl.rcParams["axes.formatter.limits"] = (-4, 4)

mpl.rcParams["axes.prop_cycle"] = mpl.cycler(color=["xkcd:royal blue", "xkcd:vermillion", "xkcd:lime",
                                  "xkcd:yellow", "xkcd:orange", "xkcd:magenta", "grey"])

mpl.rcParams["lines.linewidth"] = 2
mpl.rcParams["axes.linewidth"] = .5

mpl.rcParams["font.size"] = 12

mpl.rcParams["text.usetex"] = True


#mpl.rcParams["figure.facecolor"] = "#fffbf0"
#mpl.rcParams["axes.facecolor"] = "#fffbf0"
#mpl.rcParams["savefig.facecolor"] = '#fffbf0'

# %% [markdown]
# Usefull functions

# %%
def get_extent(file, firstline):
    """this functions retrieves the extent of the grid (in code-units) and number of points from the grid.out 
    file in one dimension (starting at firstline)
    
    file: the grid.out file
    firstline: the line in the file to look for the number of points in that dimension"""
    with open(file, "r") as gridfile:
        lines = gridfile.readlines()
        # get the number of points
        NUM_POINTS = int(lines[firstline])

        # get the extent of the x-axis (in code units)
        # the first line of the grid, so minimum coordinate
        line = lines[firstline+1]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_min = float(parts[1])
        # the last line
        line = lines[firstline+NUM_POINTS]
        parts = line.split()
        # remove the spaces
        for part in parts:
            if part == " ":
                del part
        d_max = float(parts[2])
    
    return (NUM_POINTS, (d_min, d_max))

# %% [markdown]
# ## get metadata of the simulation data

# %%
# specify the directories where the data is stored and where the output should be stored
DATA_DIR = "out-raw-Buniform/low-beta05/"
OUT_DIR = "images/"

# define the conversion factors, can be seen when starting the simulation
UNIT_DENSITY = 1e9*CONST_mp
UNIT_LENGTH = 1e8 # cm (1AU)
UNIT_VELOCITY = 1e8 # cm/s
UNIT_TIME = UNIT_LENGTH/UNIT_VELOCITY
UNIT_PRESSURE = 1.673e1   # dyne/cm^2

# %%
# get info about the stored data
file_data = pd.read_csv(DATA_DIR+"dbl.out", sep=" ", names=["index", "t", "dt", "step", "type", "little", "rho",
                                                            "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"])
# delete columns that are not needed
for column in ["index", "type", "little", "rho", "vx1", "vx2", "vx3", "Bx1", "Bx2", "Bx3", "prs", "psi_glm", "empty"]:
    del file_data[column]

X_POINTS = 0
Y_POINTS = 0
X_EXTENT = (0,0)
Y_EXTENT = (0,0)

# get the extend of the grid
# get the extent of the x-axis (in code units)
X_POINTS, X_EXTENT = get_extent(DATA_DIR+"grid.out", 9)
# get the extent of the y-axis
Y_POINTS, Y_EXTENT = get_extent(DATA_DIR+"grid.out", 10+X_POINTS)

# number of files saved
N = len(file_data["t"])

# physical extent of the grid
extent_temp = X_EXTENT + Y_EXTENT
extent = [value*UNIT_LENGTH for value in extent_temp]
# physical time data
T = file_data["t"].values*UNIT_TIME

# %% [markdown]
# Names of all directories containing data, with extra info about beta and pressure

# %%
sims = [
    {"directory":"beta01/", "beta":0.1, "low":False},
    {"directory":"beta05/", "beta":0.5, "low":False},
    {"directory":"beta1/", "beta":1, "low":False},
    {"directory":"beta10/", "beta":10, "low":False},
    {"directory":"low-beta01/", "beta":0.1, "low":True},
    {"directory":"low-beta05/", "beta":0.5, "low":True},
    {"directory":"low-beta1/", "beta":1, "low":True},
    {"directory":"low-beta10/", "beta":10, "low":True},
]

# %% [markdown]
# ## Combined plots

# %%
for n in range(N+1):
    fig, ax = plt.subplots(2,4, figsize=(6,4))

    prs_array = []
    min_prs = [1,1]
    max_prs = [1,1]

    ex = [x*1e-8 for x in extent]

    # simulations with high pressure
    for i in range(4):
        DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
        D = pp.pload(n, w_dir=DATA_DIR+"/")
        var = D.prs
        prs_array.append(var)
        # find the min and max pressure
        if (m := np.min(var)) < min_prs[0]:
            min_prs[0] = m
        if (m := np.max(var)) > max_prs[0]:
            max_prs[0] = m
        del D

    print(min_prs[0],max_prs[0])

    # simulations with low pressure
    for i in range(4,8):
        DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
        D = pp.pload(n, w_dir=DATA_DIR+"/")
        var = D.prs

        prs_array.append(var)
        # find the min and max pressure
        if (m := np.min(var)) < min_prs[1]:
            min_prs[1] = m
        if (m := np.max(var)) > max_prs[1]:
            max_prs[1] = m
        del D

    for i in range(8):
        m = min_prs[i//4]
        M = max_prs[i//4]
        row = i//4
        column = i%4
        axis = ax[row][column]
        # prevent clutter
        ax[row][column].get_xaxis().set_visible(False)
        ax[row][column].get_yaxis().set_visible(False)
        im = ax[row][column].imshow(prs_array[i]*UNIT_PRESSURE, vmin=m*UNIT_PRESSURE, 
                            vmax=M*UNIT_PRESSURE, cmap="plasma", extent=ex)
        if sims[i]["low"] and i//4==0:
            ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])
        elif i//4==0:
            ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])

        if i%4==3:
            cbar = fig.colorbar(im, ax=axis, fraction=0.046, pad=0.02)


    # axis labels
    fig.text(0.5, 0.03, r"distance $[10^8cm]$", va='center')
    fig.text(0.02, 0.45, r"distance $[10^8cm]$", va='center', rotation=90)
    fig.text(0.96, 0.57, r"pressure $[dyne/cm^2]$", va="center", rotation=270)

    # switch the axes on the side on
    for column in range(4):
        ax[1][column].get_xaxis().set_visible(True)
    for row in range(2):
        ax[row][0].get_yaxis().set_visible(True)

    del prs_array


    fig.suptitle("time: %.2e s" %T[n], y=0.98)    

    plt.tight_layout()

    fig.savefig("out-image/combined/pressure-%02d.png" %n, dpi=300)
    plt.close(fig=fig)
# Out:
# Reading Data file : out-raw-Buniform/beta01//data.0000.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0000.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0000.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0000.dbl
# 1 5.0
# Reading Data file : out-raw-Buniform/low-beta01//data.0000.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0000.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0000.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0000.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0001.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0001.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0001.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0001.dbl
# 0.9783324728864162 4.999999988507401
# Reading Data file : out-raw-Buniform/low-beta01//data.0001.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0001.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0001.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0001.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0002.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0002.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0002.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0002.dbl
# 0.9458599466124564 3.8249569841941873
# Reading Data file : out-raw-Buniform/low-beta01//data.0002.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0002.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0002.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0002.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0003.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0003.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0003.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0003.dbl
# 0.5889520989227272 2.6023643198734496
# Reading Data file : out-raw-Buniform/low-beta01//data.0003.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0003.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0003.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0003.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0004.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0004.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0004.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0004.dbl
# 0.25702667084148734 2.5748829374987925
# Reading Data file : out-raw-Buniform/low-beta01//data.0004.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0004.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0004.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0004.dbl
# Reading Data file : out-raw-Buniform/beta01//data.0005.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0005.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0005.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0005.dbl
# 0.6915759027256275 2.5978216816795134
# Reading Data file : out-raw-Buniform/low-beta01//data.0005.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0005.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.
dbl
# Reading Data file : out-raw-Buniform/beta10//data.0028.dbl
# 0.7698626523089073 2.149341378284659
# Reading Data file : out-raw-Buniform/low-beta01//data.0028.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0028.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0028.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0028.dbl
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-49-416474fb6944> in <module>
#       1 for n in range(N+1):
# ----> 2     fig, ax = plt.subplots(2,4, figsize=(6,4))
#       3
#       4     prs_array = []
#       5     min_prs = [1,1]
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1176     """
#    1177     fig = figure(**fig_kw)
# -> 1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#    1180                        gridspec_kw=gridspec_kw)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/figure.py in subplots(self, nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw)
#    1574                 subplot_kw["sharex"] = shared_with[sharex]
#    1575                 subplot_kw["sharey"] = shared_with[sharey]
# -> 1576                 axarr[row, col] = self.add_subplot(gs[row, col], **subplot_kw)
#    1577
#    1578         # turn off redundant tick labeling
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1417                     self._axstack.remove(ax)
#    1418
# -> 1419             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1420
#    1421         return self._add_axes_internal(key, a)
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      74
#      75         # _axes_class is set in the subplot_class_factory
# ---> 76         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      77         # add a layout box to this, for both the full axis, and the poss
#      78         # of the axis.  We need both because the axes may become smaller
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     452
#     453         self._rasterization_zorder = None
# --> 454         self.cla()
#     455
#     456         # funcs used to format x and y - fall back on major formatters
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axes/_base.py in cla(self)
#    1078
#    1079         self.xaxis.set_clip_path(self.patch)
# -> 1080         self.yaxis.set_clip_path(self.patch)
#    1081
#    1082         self._shared_x_axes.clean()
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in set_clip_path(self, clippath, transform)
#     967     def set_clip_path(self, clippath, transform=None):
#     968         martist.Artist.set_clip_path(self, clippath, transform)
# --> 969         for child in self.majorTicks + self.minorTicks:
#     970             child.set_clip_path(clippath, transform)
#     971         self.stale = True
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in __get__(self, instance, cls)
#     701             else:
#     702                 instance.minorTicks = []
# --> 703                 tick = instance._get_tick(major=False)
#     704                 instance.minorTicks.append(tick)
#     705                 return instance.minorTicks
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick(self, major)
#    2228         else:
#    2229             tick_kw = self._minor_tick_kw
# -> 2230         return YTick(self.axes, 0, '', major=major, **tick_kw)
#    2231
#    2232     def _get_label(self):
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156
#     157         self.tick1line = self._get_tick1line()
# --> 158         self.tick2line = self._get_tick2line()
#     159         self.gridline = self._get_gridline()
#     160         self.label1 = self._get_text1()
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/axis.py in _get_tick2line(self)
#     590         'Get the default line2D instance'
#     591         # x in axes coords, y in data coords
# --> 592         l = mlines.Line2D((1,), (0,),
#     593                           color=self._color,
#     594                           marker=self._tickmarkers[1],
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     376         self._color = None
#     377         self.set_color(color)
# --> 378         self._marker = MarkerStyle(marker, fillstyle)
#     379
#     380         self._markevery = None
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/markers.py in __init__(self, marker, fillstyle)
#     223         self._marker_function = None
#     224         self.set_fillstyle(fillstyle)
# --> 225         self.set_marker(marker)
#     226
#     227     def _recache(self):
#
# ~/.virtualenvs/studie/lib/python3.8/site-packages/matplotlib/markers.py in set_marker(self, marker)
#     276         elif isinstance(marker, str) and cbook.is_math_text(marker):
#     277             self._marker_function = self._set_mathtext_path
# --> 278         elif isinstance(marker, Path):
#     279             self._marker_function = self._set_path_marker
#     280         elif (isinstance(marker, Sized) and len(marker) in (2, 3) and
#
# KeyboardInterrupt:

# %% [markdown]
# ### experimenteren lay-out plots

# %%
n = 15

fig, ax = plt.subplots(2,4, figsize=(6,4))

prs_array = []
min_prs = [1,1]
max_prs = [1,1]

ex = [x*1e-8 for x in extent]

# simulations with high pressure
for i in range(4):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs
    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[0]:
        min_prs[0] = m
    if (m := np.max(var)) > max_prs[0]:
        max_prs[0] = m
    del D

print(min_prs[0],max_prs[0])
    
# simulations with low pressure
for i in range(4,8):
    DATA_DIR = "out-raw-Buniform/" + sims[i]["directory"]
    D = pp.pload(n, w_dir=DATA_DIR+"/")
    var = D.prs
    
    prs_array.append(var)
    # find the min and max pressure
    if (m := np.min(var)) < min_prs[1]:
        min_prs[1] = m
    if (m := np.max(var)) > max_prs[1]:
        max_prs[1] = m
    del D

for i in range(8):
    m = min_prs[i//4]
    M = max_prs[i//4]
    row = i//4
    column = i%4
    axis = ax[row][column]
    # prevent clutter
    ax[row][column].get_xaxis().set_visible(False)
    ax[row][column].get_yaxis().set_visible(False)
    im = ax[row][column].imshow(prs_array[i]*UNIT_PRESSURE, vmin=m*UNIT_PRESSURE, 
                        vmax=M*UNIT_PRESSURE, cmap="plasma", extent=ex)
    if sims[i]["low"] and i//4==0:
        ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    elif i//4==0:
        ax[row][column].set_title(r"$\beta=$%.2f" %sims[i]["beta"])
    
    if i%4==3:
        cbar = fig.colorbar(im, ax=axis, fraction=0.046, pad=0.02)
    

# axis labels
fig.text(0.5, 0.03, r"distance $[10^8cm]$", va='center')
fig.text(0.02, 0.45, r"distance $[10^8cm]$", va='center', rotation=90)
fig.text(0.96, 0.57, r"pressure $[dyne/cm^2]$", va="center", rotation=270)

# switch the axes on the side on
for column in range(4):
    ax[1][column].get_xaxis().set_visible(True)
for row in range(2):
    ax[row][0].get_yaxis().set_visible(True)

del prs_array


fig.suptitle("time: %.2e s" %T[n], y=0.98)    

plt.tight_layout()

#fig.savefig("out-image/combined/pressure-%02d.png" %n, dpi=300)
#plt.close(fig=fig)
plt.show()
# Out:
# Reading Data file : out-raw-Buniform/beta01//data.0015.dbl
# Reading Data file : out-raw-Buniform/beta05//data.0015.dbl
# Reading Data file : out-raw-Buniform/beta1//data.0015.dbl
# Reading Data file : out-raw-Buniform/beta10//data.0015.dbl
# 0.7611382355351661 2.5513093773882822
# Reading Data file : out-raw-Buniform/low-beta01//data.0015.dbl
# Reading Data file : out-raw-Buniform/low-beta05//data.0015.dbl
# Reading Data file : out-raw-Buniform/low-beta1//data.0015.dbl
# Reading Data file : out-raw-Buniform/low-beta10//data.0015.dbl

# %% [markdown]
# ## Individual plots

# %%
sim = sims[5]
n = 14

D = pp.pload(n, w_dir="out-raw/"+sim["directory"])

fig, ax = plt.subplots(1,1)

##im=ax.imshow(np.log(plotvar[i]), vmin=np.log(MIN), vmax=np.log(MAX), cmap="plasma")
##im=ax.imshow(D.prs, cmap="plasma", extent=extent, vmin=8, vmax=16)
im=ax.imshow(D.Bx1*UNIT_PRESSURE, cmap="viridis", extent=extent)
cbar = fig.colorbar(im, ax=ax)
cbar.ax.set_ylabel('pressure [$dyne/cm^2$]', rotation=270, labelpad=15.0)


### streamlines for magnetic field
side = np.linspace(extent[0], extent[1], 1024)
X, Y = np.meshgrid(side, side)
#ax.streamplot(X, Y, D.Bx1, D.Bx2, maxlength=2000, linewidth=1, 
#              color=np.sqrt(D.Bx1**2+D.Bx2**2), 
#              density=4, arrowsize=0, cmap="winter")

if sim["low"]:
    plt.title(r"low pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"],T [n]), pad=15.0)
else:
    plt.title(r"high pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"], T[n]), pad=15.0)
ax.set_xlabel("x-axis [cm]")
ax.set_ylabel("y-axis [cm]")
# Out:
# Reading Data file : out-raw/low-beta05/data.0014.dbl
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-b7e2f59b0969> in <module>
#      21
#      22 if sim["low"]:
# ---> 23     plt.title(r"low pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"],T [n]), pad=15.0)
#      24 else:
#      25     plt.title(r"high pressure difference; $\beta=$ %f; time: %.3e s" %(sim["beta"], T[n]), pad=15.0)
#
# IndexError: index 14 is out of bounds for axis 0 with size 11

# %%
img = imread('test-image.png')

plt.imshow(img)
